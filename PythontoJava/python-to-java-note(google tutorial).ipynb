# %% [markdown]
# ## Python to Java

# %% [markdown]
# ### Q & A
#
#
#
# - **What does compiling do for us? **
#
#     early detection error
#
#     Faster Program Execution
#
#     > The complier will turns java code into byte code, since byte code is much closer to the native language of the computer it can run faster.
#
#
# - **Basic Java Rule**
#
#     - Every Java program must define a class, all code is inside a class.
#
#     - Everything in Java must have a type (same as c++)
#
#     - Every Java program must have a function called $\hspace{1cm}$
#
#             Java:
#
#             public static void main(String[] args) {}
#
#             python:
#
#             if __name__ == "__main__": ...
#
#
#
# - **Public? Statics? Void?**
#
#     **public** indicates to the Java compiler that this is a method that anyone can call. We will see that Java enforces several levels of security on the methods we write, including **public, protected, and private** methods.
#
#         python:
#
#         class ...
#             def pub(self,...):
#
#             def __pri__(self,...):
#
#     **static** tells Java that this is a method that is part of the class, but is not a method for any one instance of the class. For example of instance, we can think about cars is a class, and my car is one instance of that class. A specific example in Python will be `math.sin(90)`
#
#         python:
#
#         class Hello(object):
#             @staticmethod
#             def main(args):
#                 print "Hello World!"
#
#     **void** tells the Java compiler that the method/function **will not** return a value! (aka return no type)

# %%
class Hello(object):
    @staticmethod
    def main(args):
        print "Hello World!"

# %%
def main():
    fahr = float(input("Enter the temperature in F: "))
    cel = (fahr - 32) * 5.0/9.0
    print "the temperature in C is: ", cel

main()
# Out:
# Enter the temperature in F: 3
# the temperature in C is:  -16.1111111111

# %% [markdown]
# - [**import?**](http://interactivepython.org/runestone/static/java4python/Java4Python.html)
#
#     In Java you can use any class that is available without having to import the class subject to two very important conditions:
#
#     > The javac and java must know that the class exists.
#
#     > You must use the full name of the class
#
#
# - **String Operation**
#
#         String name
#
# Python	|Java	|Description
# ---|---|---
# str[3]	| str.charAt(3)	|Return character in 3rd position
# str[2:5]|	str.substring(2,4)|	Return substring from 2nd to 4th
# len(str)|	str.length()	|Return the length of the string
# str.find('x')|	str.indexOf('x')	|Find the first occurrence of x
# str.split()|	str.split('\s')	|Split the string on whitespace into a list/array of strings
# str.split(',')|	str.split(',')	|Split the string at ',' into a list/array of strings
# str + str|	str.concat(str)	|Concatenate two strings together
# str.strip()|	str.trim()	|Remove any whitespace at the beginning or end
# [for c in str] | str.toCharArray() | get array
#
# - **Array List**
#
#     Strictly speaking it is not necessary to give the ArrayList any size. It will grow or shrink dynamically as needed just like a list in Python.
#
#         ArrayList<type> name
#
# Python	|Java	|Description
# ---|---|---
# list[3] = 1	| list.set(3,1)	|set the value at 3rd position
# list[3] | list.get(3) | get the value at 3rd position
# for i in list | for (Integer i : list) | for loop on list
#
#
# - **Array**
#
#     We can initialize short arrays directly using something like python.
#
#         type[] name = {..,..,.};
#
#         name[idx] = name[idx] + 1
#
#
# - **Dictionary(Map)**
#
#     Java provides two different implementations of a map, one is called the TreeMap and the other is called a HashMap. As you might guess the TreeMap uses a balanced binary tree behind the scenes, and the HashMap uses a hash table.
#
#         TreeMap<String,Integer> count;
#
#         count = new TreeMap<String,Integer>();
#
#
# Python	|Java	|Description
# ---|---|---
# dict[3] += 1	| dict.put(3,++dict.get(3))	|set the value for key 3
# dict[3] | dict.get(3) | get the value at 3rd position (java can get null value)
#
#
# - **Conditionals**
#
#      ** Java does not have an elif pattern like Python. In Java you can get the functionality of an elif statement by nesting if and else. ** @_@
#
#      Therefore, what we can do is
#
#              if(){}
#              else{
#                   if(){}
#                   else{
#                        if(){}
#                        else{ ...}}}
#
#      Since the if is the only statement used in each else we can get away with the following!!
#
#              if(){}
#              else if(){}
#              else if(){}
#              else if(){}
#              else {}
#
#
# Python	|Java
# ---|---
# `if` *condition* :	| `if` (*condition*){}
# `if:...else:...` | `if(){...}else:{...}`
#
#
#
# - **Switch**
#
#     Q:  why python doesn't have this?
#
#     Short A: You can do this easily enough with a sequence of if elif. More easily, you can use dictionary mapping for functions and dispatch methods for classes.
#
#     The below code is an example. However, it's kinda inconvenient using switch since if we forget to put in the **break** statement, then the next alternative will be automatically executed.
#
#
#         switch(argument) {
#         case 0:
#             System.out.println('Hi');
#             break;
#         case 1:
#             System.out.println('Lenny');
#             break;
#         case 2:
#             System.out.println('Fan');
#             break;
#         default:
#             System.out.println('Nope');
#             break;
#         };
#
#
# - **Boolean Shortcut**
#
#         Python
#
#         rtn = trueValue if condition else falseValue
#
#         Java
#
#         Boolean rtn;
#         rtn = condition ? trueValue : falseValue;
#
#
# - **for Loop**
#
#
# Python	|Java
# ---|---
# `for i in range(sta,end,step):`	| `for (Integer i = sta; i <= end; i += step){}`
# `for i in list` | `for (Integer i : list){}`
#
#
#         ##More detail
#         Java
#
#         #ArrayList
#
#         ArrayList<Integer> l = new ArrayList<Integer>();
#         l.add(1); l.add(1); l.add(2); l.add(3);
#         for (Integer i : l) {
#             System.out.println(i)
#         }
#
#         #Array
#         String[] l = {"g","g","i","n","i","n"};
#         for (String i : l) {
#             System.out.println(i)
#         }
#
#
#         #String
#         String s = "Hi World";
#         for (char c : s.toCharArray()) {
#             System.out.println(c);
#         }
#
#
# - **while loop**
#
#     Basically, they are same. But Java support some function like C++
#
#         do{...} while(condition);
#
#         while(condition) {...}

# %% [markdown]
# ## Class
#
#    As mentioned before, Not like Python, its unavoidable for even the simplest of programs in Java to use Class.
#    I will use the example from [Google tutorial](http://interactivepython.org/runestone/static/java4python/Java4Python.html).
#
#    Not like Python, any instance variable in class need to be declared in Java. The declarations of instance variables can come at the beginning of the class definition or the end.
#
#         public class Fraction {
#         private Integer numerator;
#         private Integer denominator;
#         }
#
#    Notice that we have declared the variables to be **private**, which means we can't access to instance variables directly from outside of the class. Therefore, if we want to get or set value, we must write a function to get or set it.
#
#        public Integer getNumerator() {
#             return numerator;
#         }
#
#        public void setNumerator(Integer numerator) {
#             this.numerator = numerator;
#         }
#
# ### Construction
#
#    The next thing to consider is the constructor. In Java, constructors have the same name as the class and are declared public. They are declared without a return type. The Construction kinda like `__init__()` in Python.
#
#        public Fraction(Integer top, Integer bottom) {
#         num = top;
#         den = bottom;
#         }
#
#    Notice that we didn't call self.num aboce, because the Java compiler will do the work of dereferencing the current Java object. We only need `self` when we need to differentiate between a parameter or local variable and an instance variable.
#
#        public Fraction(Integer num, Integer den) {
#         this.num = num;
#         this.den = den;
#         }
#
#
# ### Method / Member furnction
#
#    First, in Java, there is **no operator overloading**. Therefore, we **can't d**o something like
#
#        def __add__(self,other)
#            return...
#        fraction(a,b) + fraction(c,d) >> error in Java
#
#    Instead, we will have to write member functions
#
#        public Fraction add(Fraction otherFrac) {
#         # Declare
#         Integer newNum, newDen, common;
#         ..... ;
#         return new Fraction(newNum/common, newDen/common );
#         }
#
#
# ### Overloading
#
#    However, how are we going to deal with different types of input. Note that in Java, we declared the type in the beginning. The way that we solve this problem is by writing another add method with a different set of parameters. In Java this practice is legal and common we call this practice overloading.
#
#
#        public Fraction(Integer num) {
#             this.numerator = num;
#             this.denominator = 1;
#         }
#
#        public Fraction add(Integer other) {
#             return add(new Fraction(other));
#         }
#
# ### Some other default Function
#
#    The object class provides default implementations.
#
#    `clone | equals | finalize | getClass | hashCode | notify | notifyAll |toString | wait`
#
#    For example,
#
#        Python:
#
#        def __str__(self):...
#
#
#        Java:
#
#        Public String toString() { return ; }
#
#        public boolean equals(Fraction other) { if () return True; else return False; }

# %% [markdown]
# ## Abstract Classes and Methods
#
#    In Java an abstract class is more than just a placeholder for common functions. In Java an abstract class has the power to specify certain functions that all of its children must implement. For example, **Number** is an abstract class of double, integer, float and long. Thus, if a function or variable declared as *Number*, the input value can be any childern class of number such as integer. Therefore, if we want to extend our Fraction class behave like Integer, Double, and the other numeric classes in Java We need to make a couple of additional modifications to the class.
#
#        public class Fraction extends Number {
#             ...
#         }
#
#    The keyword extends tells the compiler that the class Fraction extends, or adds new functionality to the Number class. A child class always extends its parent.
#
#    However, and this is a big however, it is also important to remember that **if you specify Number as the type on a particular parameter** then **the Java compiler will only let you use the methods of a Number**. In this case longValue, intValue, floatValue, and doubleValue. It means that we can't use the methods we defined in Fraction.
#
#
# ## [Interfaces ( customized sort )](http://interactivepython.org/runestone/static/java4python/Java4Python.html)
#
#    In Python, we can define `__cmp__`. In Java Things that are sortable must be **Comparable**. For the example above,
#
#        public class Fraction extends Number implements Comparable<Fraction> {
#             public int compareTo(Fraction other) {
#                 Integer num1 = this.numerator * other.getDenominator();
#                 Integer num2 = this.denominator * other.getNumerator();
#                 return num1 - num2;
#             }
#         }

# %% [markdown]
# ## Common Mistake
#
# - Forgetting to declare variables.
#
#     Remember it does not like **Python*
#
# - Not importing a class
#
# - **Forgetting to use the new keyword to create an object**
#
#     Remember to put `new` in the beginning if intializing a consturcter

# %% [markdown]
# ### Reference
#
#    [Google: Python to Java](http://interactivepython.org/runestone/static/java4python/Java4Python.html)
